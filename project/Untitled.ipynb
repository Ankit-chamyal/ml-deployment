# %%
 # step1_data_preprocessing.py

import pandas as pd

# Load the dataset
df = pd.read_csv("C:/Users/DELL/Desktop/project/balanced_heart_disease_dataset.csv")

# Display basic info
print(df.info())
print(df.head())
print(df.describe())

# Check for null values
print("Null values per column:\n", df.isnull().sum())

# Clean column names (strip and lower-case)
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# Check for duplicates
duplicate_count = df.duplicated().sum()
print(f"Duplicate rows: {duplicate_count}")
df = df.drop_duplicates()

# Save cleaned dataset
df.to_csv("cleaned_heart_disease_dataset.csv", index=False)
print("✅ Cleaned dataset saved as cleaned_heart_disease_dataset.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1200 non-null   int64
#  1   sex       1200 non-null   int64
#  2   cp        1200 non-null   int64
#  3   trestbps  1200 non-null   int64
#  4   chol      1200 non-null   int64
#  5   fbs       1200 non-null   int64
#  6   restecg   1200 non-null   int64
#  7   thalach   1200 non-null   int64
#  8   exang     1200 non-null   int64
#  9   oldpeak   1200 non-null   float64
#  10  slope     1200 non-null   int64
#  11  ca        1200 non-null   int64
#  12  thal      1200 non-null   int64
#  13  target    1200 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 131.4 KB
# None
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   26    1   0       104   256    1        0      120      0      2.7      2
# ...
